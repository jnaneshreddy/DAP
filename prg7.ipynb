# %%
import numpy as np 
import matplotlib.pyplot as plt
m=5 
n=7 
arr=np.random.randint(100,size=(m,n))
print(arr)
print(arr.shape)
print(arr.size)
print(arr.T)
print(arr.dtype)
print(arr.ndim)
print(arr.itemsize)
print(arr.data)
plt.imshow(arr)
plt.show()
# Out:
# [[55 42 13 27 36 53 89]
#  [59 53 57  0 30 86 72]
#  [82  5 30 38 32 18 72]
#  [ 5 57 83 89 91 83 80]
#  [46  1 34 74 19 88 94]]
# (5, 7)
# 35
# [[55 59 82  5 46]
#  [42 53  5 57  1]
#  [13 57 30 83 34]
#  [27  0 38 89 74]
#  [36 30 32 91 19]
#  [53 86 18 83 88]
#  [89 72 72 80 94]]
# int32
# 2
# 4
# ...
